# %%
# !unzip /content/drive/MyDrive/pneumonia_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: chest_xray/train/NORMAL/NORMAL-2558319-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2558319-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2559035-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2559035-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2565226-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2568157-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2597757-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2597757-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-263932-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2646645-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2646923-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2655558-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2659844-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-2675017-0001.jpeg
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.3/721.3 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 62.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 67.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 86.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.4 MB/s eta 0:00:00
# ...

# %%
model=YOLO('yolov8n-cls')
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 247MB/s]

# %%
history = model.train(data='/content/chest_xray',epochs=10)
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import files
files.download("/content/runs")

# %%
# !zip -r /content/runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/classify/ (stored 0%)
#   adding: content/runs/classify/train/ (stored 0%)
#   adding: content/runs/classify/train/train_batch0.jpg (deflated 3%)
#   adding: content/runs/classify/train/weights/ (stored 0%)
#   adding: content/runs/classify/train/weights/best.pt (deflated 9%)
#   adding: content/runs/classify/train/weights/last.pt (deflated 9%)
#   adding: content/runs/classify/train/val_batch2_pred.jpg (deflated 4%)
#   adding: content/runs/classify/train/val_batch0_labels.jpg (deflated 5%)
#   adding: content/runs/classify/train/confusion_matrix_normalized.png (deflated 34%)
#   adding: content/runs/classify/train/events.out.tfevents.1710604403.272793821acc.506.0 (deflated 93%)
#   adding: content/runs/classify/train/train_batch2.jpg (deflated 5%)
#   adding: content/runs/classify/train/val_batch1_labels.jpg (deflated 3%)
#   adding: content/runs/classify/train/args.yaml (deflated 52%)
# ...

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
# Assuming you have already trained the model, you can load it using:
# model = YOLO('path/to/your/trained/model.pt')

# Perform inference on the test dataset
results = model('/content/chest_xray/test/NORMAL')  # Replace '/path/to/test/images' with the path to your test images

# Access model predictions and ground truth annotations
predictions = results.pred
ground_truth = results.gt
# Out:
# image 1/234 /content/chest_xray/test/NORMAL/NORMAL-1049278-0001.jpeg: 224x224 NORMAL 0.97, PNEUMONIA 0.03, 3.6ms
# image 2/234 /content/chest_xray/test/NORMAL/NORMAL-1110860-0001.jpeg: 224x224 NORMAL 1.00, PNEUMONIA 0.00, 3.7ms
# image 3/234 /content/chest_xray/test/NORMAL/NORMAL-11419-0001.jpeg: 224x224 NORMAL 1.00, PNEUMONIA 0.00, 3.3ms
# image 4/234 /content/chest_xray/test/NORMAL/NORMAL-115218-0001.jpeg: 224x224 NORMAL 0.99, PNEUMONIA 0.01, 3.4ms
# image 5/234 /content/chest_xray/test/NORMAL/NORMAL-1160949-0001.jpeg: 224x224 NORMAL 1.00, PNEUMONIA 0.00, 3.6ms
# image 6/234 /content/chest_xray/test/NORMAL/NORMAL-1212407-0001.jpeg: 224x224 NORMAL 0.82, PNEUMONIA 0.18, 4.3ms
# image 7/234 /content/chest_xray/test/NORMAL/NORMAL-1228182-0001.jpeg: 224x224 NORMAL 1.00, PNEUMONIA 0.00, 3.7ms
# image 8/234 /content/chest_xray/test/NORMAL/NORMAL-1283091-0001.jpeg: 224x224 NORMAL 0.95, PNEUMONIA 0.05, 3.4ms
# ...

# %%
# Perform inference on the test dataset
results = model('/content/chest_xray/test/NORMAL')  # Replace '/content/chest_xray/test' with the path to your test images

# Check if results contain predictions
if isinstance(results, list):
    print("Error: Inference failed. Please check your input data or model.")
else:
    # Access model predictions and ground truth annotations
    predictions = results.pred
    ground_truth = results.gt
# Out:
# image 1/234 /content/chest_xray/test/NORMAL/NORMAL-1049278-0001.jpeg: 224x224 NORMAL 0.97, PNEUMONIA 0.03, 5.0ms
# image 2/234 /content/chest_xray/test/NORMAL/NORMAL-1110860-0001.jpeg: 224x224 NORMAL 1.00, PNEUMONIA 0.00, 4.5ms
# image 3/234 /content/chest_xray/test/NORMAL/NORMAL-11419-0001.jpeg: 224x224 NORMAL 1.00, PNEUMONIA 0.00, 4.7ms
# image 4/234 /content/chest_xray/test/NORMAL/NORMAL-115218-0001.jpeg: 224x224 NORMAL 0.99, PNEUMONIA 0.01, 10.5ms
# image 5/234 /content/chest_xray/test/NORMAL/NORMAL-1160949-0001.jpeg: 224x224 NORMAL 1.00, PNEUMONIA 0.00, 6.3ms
# image 6/234 /content/chest_xray/test/NORMAL/NORMAL-1212407-0001.jpeg: 224x224 NORMAL 0.82, PNEUMONIA 0.18, 4.7ms
# image 7/234 /content/chest_xray/test/NORMAL/NORMAL-1228182-0001.jpeg: 224x224 NORMAL 1.00, PNEUMONIA 0.00, 4.3ms
# image 8/234 /content/chest_xray/test/NORMAL/NORMAL-1283091-0001.jpeg: 224x224 NORMAL 0.95, PNEUMONIA 0.05, 4.8ms
# ...
